# %%
file="SORTED_DATA"
myfile=open(file)

# %%
import pandas
import savefig
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-c47d5aa15a25> in <module>
#       1 import pandas
# ----> 2 import savefig
#
# ModuleNotFoundError: No module named 'savefig'

# %%
pandas.set_option('display.max_rows',10)
pandas.DataFrame.from_csv(myfile)
# Out:
# D:\anish\Documents\RESEARCH\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#           A                     N   L.1        H     a   r  d  w  a.1  ...  \
# L                                                                      ...
# 0         7             115109112     1     8  8     0  16  3  3    0  ...
# 2066      7             115109112     1     8  8     0  16  3  3    0  ...
# 2225      7             115109112     1     8  8     0  16  3  3    0  ...
# 5240      7             115109112     1     8  8     0  16  3  3    0  ...
# 16385     7             115109112     1     8  8     0  16  3  3    0  ...
# ...      ..                   ...   ...   ... ..   ...  .. .. ..  ...  ...
# 5406762  18  99108117115116101114  1024  4096  4   378   8  2  2    2  ...
# ...
